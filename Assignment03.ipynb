# %% [markdown]
# <a href="https://colab.research.google.com/github/RajaAbitha/RajaAbitha/blob/main/Assignment03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
df = pd.read_csv('/content/diabetes(1).csv')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Checking missing values
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# Replace Zeros with NaN

cols_with_zero_as_nan = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']
df[cols_with_zero_as_nan] = df[cols_with_zero_as_nan].replace(0, np.nan)

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0           35.0      NaN  33.6
# 1            1     85.0           66.0           29.0      NaN  26.6
# 2            8    183.0           64.0            NaN      NaN  23.3
# 3            1     89.0           66.0           23.0     94.0  28.1
# 4            0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Fill missing values with median
df[cols_with_zero_as_nan] = df[cols_with_zero_as_nan].fillna(df[cols_with_zero_as_nan].median())

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0           35.0    125.0  33.6
# 1            1     85.0           66.0           29.0    125.0  26.6
# 2            8    183.0           64.0           29.0    125.0  23.3
# 3            1     89.0           66.0           23.0     94.0  28.1
# 4            0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
x=df.drop('Outcome',axis=1)
y=df['Outcome']

# %%
# split the dataset
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# Scale the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(x_train)
X_test_scaled = scaler.transform(x_test)

# %%
lr = LogisticRegression()
lr.fit(X_train_scaled, y_train)
y_pred = lr.predict(X_test_scaled)

print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7532467532467533

# %%
# Evaluate the model
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
print('Accuracy Linear Regression:',accuracy_score(y_test,y_pred))
# Out:
# Accuracy Linear Regression: 0.7532467532467533

# %%
# confusion metrix
print(confusion_matrix(y_test,y_pred))
# Out:
# [[82 17]
#  [21 34]]

# %%
_# classification report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.83      0.81        99
#            1       0.67      0.62      0.64        55
#
#     accuracy                           0.75       154
#    macro avg       0.73      0.72      0.73       154
# weighted avg       0.75      0.75      0.75       154

# %%
# Random forest model
from sklearn.ensemble import RandomForestClassifier
model1=RandomForestClassifier()
model1.fit(X_train_scaled,y_train)
# Out:
# RandomForestClassifier()

# %%
# Evaluation
y_pred1=model1.predict(X_test_scaled)
print('Accuracy Random Forest:',accuracy_score(y_test,y_pred1))
# Out:
# Accuracy Random Forest: 0.7857142857142857

# %%
# confusion metrix
print(confusion_matrix(y_test,y_pred1))
# Out:
# [[82 17]
#  [16 39]]

# %%
# Classification report
print(classification_report(y_test,y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.83      0.83        99
#            1       0.70      0.71      0.70        55
#
#     accuracy                           0.79       154
#    macro avg       0.77      0.77      0.77       154
# weighted avg       0.79      0.79      0.79       154

# %%
# Convert 0/1 to 'NO'/'YES'
# Convert predictions to labels
y_pred_labels1 = ['YES' if pred == 1 else 'NO' for pred in y_pred1]

# %%
y_pred_labels1
# Out:
# ['NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'YES',
#  'NO',
#  'YES',
#  'YES',
#  'YES',
#  'NO',
#  'YES',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'YES',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'YES',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'YES',
#  'NO',
#  'YES',
#  'NO',
#  'NO',
#  'YES',
#  'YES',
#  'NO',
#  'YES',
#  'NO',
#  'NO',
#  'NO',
#  'YES',
#  'NO',
#  'YES',
#  'YES',
#  'NO',
#  'NO',
#  'NO',
#  'YES',
#  'NO',
#  'NO',
#  'YES',
#  'YES',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'YES',
#  'NO',
#  'YES',
#  'NO',
#  'YES',
#  'YES',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'YES',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'YES',
#  'YES',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'NO',
#  'YES',
#  'NO',
#  'YES',
#  'YES',
#  'NO',
#  'YES',
#  'NO',
#  'YES',
#  'NO',
#  'YES',
#  'YES',
#  'YES',
#  'NO',
# ...

# %%
# Show Actual/ predicted results
results = pd.DataFrame({'Actual': y_test.values,
                        'Predicted': y_pred_labels1})

results.head(20)
# Out:
#     Actual Predicted
# 0        0        NO
# 1        0        NO
# 2        0        NO
# 3        0        NO
# 4        0        NO
# 5        0       YES
# 6        0        NO
# 7        0       YES
# 8        0       YES
# 9        0       YES
# 10       1        NO
# 11       0       YES
# 12       1        NO
# 13       0        NO
# 14       0        NO
# 15       1        NO
# 16       0        NO
# 17       0        NO
# 18       1       YES
# 19       1        NO
